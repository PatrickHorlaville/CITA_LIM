# %% [markdown]
# # Relative Entropy with `limlam_mocker`
#
# - This notebook is intended to present how to produce a point-wise differential relative entropy analysis over intensity maps generated through `limlam_mocker`
#
# - I suggest getting acquainted with the `limlam_mocker` general use readme first

# %% [markdown]
# Author: Patrick Horlaville

# %% [markdown]
# NOTE:
#
# - for supplemental information or any question you might have going through this readme, refer to https://arxiv.org/abs/2309.15733 (specifically, at $\S$ 2.2 & 4.3 for relative entropy discussion)
# - or contact me at : phorlaville24@ubishops.ca

# %% [markdown]
# First, read this notebook from the root limCode folder, so the imports work correctly. Therefore, this whole notebook will run as though its location is:

# %%
# %cd '/fs/lustre/scratch/horlaville/clara_limlam/limCode2020-master_clara_2/'
# Out:
# /fs/lustre/scratch/horlaville/clara_limlam/limCode2020-master_clara_2

# %% [markdown]
# Then, import all packages:

# %%
# base imports
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# various math package imports
import math
from scipy import special
from scipy import interpolate
import astropy.units as u 
from scipy.ndimage import gaussian_filter

# base intensity mapping package
from lim import lim 

# My plotting preferences
matplotlib.rcParams.update({'font.size': 18,'figure.figsize':[8,7]}) 
#plt.rcParams["mathtext.fontset"] = "dejavuserif"

# Dongwoo's plotting preferences, which I used for my paper:
plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = '\\usepackage{tgheros}\\usepackage{sansmath}\\sansmath'

# used to check on the running time of particular computations
from datetime import datetime

# %% [markdown]
# Then, we can load the lim model, here for [C II]:

# %%
# Initialize LineModel with default model
m = lim()
m_cii = lim('Lichen_v4', doSim = True)
# Out:
# Input cosmological model does not match simulations
# Setting analytic cosmology to match simulation

# %% [markdown]
# We set our simulation parameters:

# %%
m_cii.update(model_par = {'zdex': 0.4,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'},
            dnu = 2.8*u.GHz,
            nuObs = 270*u.GHz,
            Delta_nu = 40*u.GHz,
            tobs = 40000*u.h,
            Omega_field = 4*u.deg**2,
            catalogue_file = '/home/dongwooc/scratchspace/pprun_hiz_npz/COMAP_z5.8-7.9_960Mpc_seed_13819.npz')

# %%
m_cii.sigma_N
# Out:
# <Quantity 3172.81108492 Jy / sr>

# %% [markdown]
# And load the cube of intensities:

# %%
cii_cube_zdex04 = m_cii.maps
# Out:
# Loading .npz catalogues...

# %% [markdown]
# For the relative entropy analysis, we are interested in the distribution of the voxels' [C II] signal distribution from our cube:

# %%
binning = np.logspace(0, np.log10(50000), 100)
center = (binning[:-1] + binning[1:]) / 2

# %%
n_cii_zdex04, _, _ = plt.hist(cii_cube_zdex04.value.flatten(), bins = binning)

plt.xlabel('[C II] Intensity (Jy/sr)')
plt.ylabel('N')
plt.yscale('log')
plt.title('[C II] Voxel Base Signal Distribution')
# Out:
# Text(0.5, 1.0, '[C II] Voxel Base Signal Distribution')

# %%
m_cii.update(model_par = {'zdex': 0.3,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'})

# %%
cii_cube_zdex03 = m_cii.maps
# Out:
# Loading .npz catalogues...

# %%
m_cii.update(model_par = {'zdex': 0.5,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'})

# %%
cii_cube_zdex05 = m_cii.maps
# Out:
# Loading .npz catalogues...

# %%
n_cii_zdex03, _, _ = plt.hist(cii_cube_zdex03.value.flatten(), bins = binning, label = 'zdex = 0.3', histtype = 'step')
n_cii_zdex04, _, _ = plt.hist(cii_cube_zdex04.value.flatten(), bins = binning, label = 'zdex = 0.4', histtype = 'step')
n_cii_zdex05, _, _ = plt.hist(cii_cube_zdex05.value.flatten(), bins = binning, label = 'zdex = 0.5', histtype = 'step')


plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('N')
plt.yscale('log')
plt.xscale('log')
plt.title('[C II] voxel signal distribution')
plt.legend()

# %%
plt.plot(center, n_cii_zdex03, label = 'zdex = 0.3')
plt.plot(center, n_cii_zdex04, label = 'zdex = 0.4')
plt.plot(center, n_cii_zdex05, label = 'zdex = 0.5')

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('N')
plt.yscale('log')
plt.xscale('log')
plt.title('[C II] voxel signal distribution')
plt.legend()

# %%
plt.plot(center, np.log(n_cii_zdex03/n_cii_zdex04), label = '0.3/0.4')
plt.plot(center, np.log(n_cii_zdex05/n_cii_zdex04), label = '0.5/0.4')

plt.xlabel('[C II] intensity (Jy/sr)')
#plt.ylabel('N')
#plt.yscale('log')
plt.xscale('log')
#plt.title('[C II] voxel signal distribution')
plt.legend()
# Out:
# /tmp/ipykernel_3286770/1652695955.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(center, np.log(n_cii_zdex03/n_cii_zdex04), label = '0.3/0.4')

# %%
plt.plot(center, n_cii_zdex04*(np.log(n_cii_zdex05/n_cii_zdex04) - np.log(n_cii_zdex03/n_cii_zdex04)))

plt.xlabel('[C II] intensity (Jy/sr)')
#Àplt.ylabel('N')
#plt.yscale('log')
plt.xscale('log')
plt.title('Relative Entropy')

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], linestyle = '--', color = 'k')
# Out:
# /tmp/ipykernel_3286770/2018124029.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(center, n_cii_zdex04*(np.log(n_cii_zdex05/n_cii_zdex04) - np.log(n_cii_zdex03/n_cii_zdex04)))

# %% [markdown]
# Perform on all lightcones, across all the parameters

# %%
binning = np.logspace(1, 5, 50)
center = (binning[:-1] + binning[1:]) / 2

# %% [markdown]
# Full sig:

# %%
avg_zdex03_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_zdex0-3.npy')
avg_zdex04_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_zdex05_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_zdex0-5.npy')

# %%
avg_acii20_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_acii0-020.npy')
avg_acii24_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_acii28_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_acii0-028.npy')

# %%
avg_mhi68_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_mhi0-68.npy')
avg_mhi74_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_mhi80_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_mhi0-80.npy')

# %%
avg_mmin9_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_logmmin9-9.npy')
avg_mmin0_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_mmin1_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_logmmin10-1.npy')

# %%
avg_a013_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_a0_-1-312.npy')
avg_a014_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_a015_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_a0_-1-512.npy')

# %%
avg_g27_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_g0_0-27.npy')
avg_g31_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_basis.npy')
avg_g35_sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/sig/n_avg_g0_0-35.npy')

# %% [markdown]
# Full noise:

# %%
lin_center = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/lin_center.npy')

# %%
avg_zdex03_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_zdex0-3_alt.npy')
avg_zdex04_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis_alt.npy')
avg_zdex05_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_zdex0-5_alt.npy')

# %%
avg_acii20_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_acii0-020.npy')
avg_acii24_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis.npy')
avg_acii28_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_acii0-028.npy')

# %%
avg_mhi68_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_mhi0-68.npy')
avg_mhi74_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis.npy')
avg_mhi80_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_mhi0-80.npy')

# %%
avg_mmin9_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_logmmin9-9.npy')
avg_mmin0_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis.npy')
avg_mmin1_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_logmmin10-1.npy')

# %%
avg_a013_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_a0_-1-312.npy')
avg_a014_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis.npy')
avg_a015_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_a0_-1-512.npy')

# %%
avg_g27_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_g0_0-27.npy')
avg_g31_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_basis.npy')
avg_g35_s2 = np.load('/mnt/scratch-lustre/horlaville/nuObs270_corr/dsrel/for/for_tobs40kh/n_avg_g0_0-35.npy')

# %%
plt.plot(center, avg_zdex03_sig, label = r'$\sigma_Z$ = 0.3')
plt.plot(center, avg_zdex04_sig, label = r'$\sigma_Z$ = 0.4')
plt.plot(center, avg_zdex05_sig, label = r'$\sigma_Z$ = 0.5')

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('N')
plt.yscale('log')
plt.xscale('log')
plt.title('[C II] voxel signal distribution')
plt.legend()

plt.savefig('paper_figs/seminar_dsrel/hist_sig.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, avg_acii20_sig, label = r'$\alpha_{[CII]}$ = 0.020')
plt.plot(center, avg_acii24_sig, label = r'$\alpha_{[CII]}$ = 0.024')
plt.plot(center, avg_acii28_sig, label = r'$\alpha_{[CII]}$ = 0.028')

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('N')
plt.yscale('log')
plt.xscale('log')
plt.title('[C II] voxel signal distribution')
plt.legend()

plt.savefig('paper_figs/seminar_dsrel/hist_acii.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, avg_zdex04_sig*np.log(avg_zdex03_sig/avg_zdex04_sig), label = r'$\Delta \sigma_Z$ = 0.3/0.4')
plt.plot(center, avg_zdex04_sig*np.log(avg_zdex05_sig/avg_zdex04_sig), label = r'$\Delta \sigma_Z$ = 0.5/0.4')

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('PRE')
#plt.yscale('log')
plt.xscale('log')
plt.title('PRE per log-intensity bin')
plt.legend()

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], color = 'k', linestyle = '--')

plt.savefig('paper_figs/seminar_dsrel/pre_sig.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, avg_acii24_sig*np.log(avg_acii20_sig/avg_acii24_sig), label = r'$\Delta \alpha_{[CII]}$ = 0.020/0.024')
plt.plot(center, avg_acii24_sig*np.log(avg_acii28_sig/avg_acii24_sig), label = r'$\Delta \alpha_{[CII]}$ = 0.028/0.024')

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel('PRE')
#plt.yscale('log')
plt.xscale('log')
plt.title('PRE per log-intensity bin')
plt.legend()

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], color = 'k', linestyle = '--')

plt.savefig('paper_figs/seminar_dsrel/pre_acii.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, avg_zdex04_sig*(np.log(avg_zdex05_sig/avg_zdex04_sig) - np.log(avg_zdex03_sig/avg_zdex04_sig))/0.1)

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel(r'$\Delta$PRE/$\Delta \sigma_Z$')
#plt.yscale('log')
plt.xscale('log')
plt.title(r'$\Delta$PRE/$\Delta \sigma_Z$ per log-intensity bin')

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], color = 'k', linestyle = '--')

plt.savefig('paper_figs/seminar_dsrel/dpre_sig.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, avg_acii24_sig*(np.log(avg_acii28_sig/avg_acii24_sig) - np.log(avg_acii20_sig/avg_acii24_sig))/(0.028-0.020))

plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel(r'$\Delta$PRE/$\Delta \alpha_{[CII]}$')
#plt.yscale('log')
plt.xscale('log')
plt.title(r'$\Delta$PRE/$\Delta \alpha_{[CII]}$ per log-intensity bin')

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], color = 'k', linestyle = '--')

plt.savefig('paper_figs/seminar_dsrel/dpre_acii.pdf', bbox_inches = 'tight')

# %%
plt.plot(center, 16*avg_zdex04_sig*(np.log(avg_zdex05_sig/avg_zdex04_sig) - np.log(avg_zdex03_sig/avg_zdex04_sig))/0.2, label = r'$\sigma_Z$ (16$\times$)')
plt.plot(center, avg_acii24_sig*(np.log(avg_acii28_sig/avg_acii24_sig) - np.log(avg_acii20_sig/avg_acii24_sig))/(0.028-0.020), '--', label = r'$\alpha_{[CII]}$')
plt.plot(center, 48*avg_mhi74_sig*(np.log(avg_mhi80_sig/avg_mhi74_sig) - np.log(avg_mhi68_sig/avg_mhi74_sig))/(0.80-0.68), '-.', label = r'$\alpha_{HI}$ (48$\times$)')
plt.plot(center, -16*avg_mmin0_sig*(np.log(avg_mmin1_sig/avg_mmin0_sig) - np.log(avg_mmin9_sig/avg_mmin0_sig))/(10.1 - 9.9), '-.', label = r'log($M_{min}$) ($-$16$\times$)')
plt.plot(center, -42*avg_a014_sig*(np.log(avg_a015_sig/avg_a014_sig) - np.log(avg_a013_sig/avg_a014_sig))/(0.2), label = r'$\alpha_0$ ($-$42$\times$)')
plt.plot(center, -8*avg_g31_sig*(np.log(avg_g35_sig/avg_g31_sig) - np.log(avg_g27_sig/avg_g31_sig))/(0.08), '--', label = r'$\gamma$ ($-$8$\times$)')


plt.xlabel('[C II] intensity (Jy/sr)')
plt.ylabel(r'$\Delta$PRE/$\Delta \lambda$')
#plt.yscale('log')
plt.xscale('log')
plt.title(r'$\Delta$PRE/$\Delta \lambda$ per log-intensity bin')

plt.legend(prop={'size':15})

plt.hlines(y = 0, xmin = center[0], xmax = center[-1], color = 'k', linestyle = '--')

#plt.savefig('paper_figs/seminar_dsrel/final_slide/dpre_sigv1.pdf', bbox_inches = 'tight')

# %%
lin_center = lin_center / 1000

# %%
plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
plt.plot(lin_center, avg_acii24_s2*(np.log(avg_acii28_s2/avg_acii24_s2) - np.log(avg_acii20_s2/avg_acii24_s2))/(0.028-0.020), '--', label = r'$\alpha_{[CII]}$')
plt.plot(lin_center, 48*avg_mhi74_s2*(np.log(avg_mhi80_s2/avg_mhi74_s2) - np.log(avg_mhi68_s2/avg_mhi74_s2))/(0.80-0.68), '-.', label = r'$\alpha_{HI}$ (48$\times$)')
plt.plot(lin_center, -16*avg_mmin0_s2*(np.log(avg_mmin1_s2/avg_mmin0_s2) - np.log(avg_mmin9_s2/avg_mmin0_s2))/(10.1 - 9.9), '-.', label = r'log($M_{min}$) ($-$16$\times$)')
plt.plot(lin_center, -42*avg_a014_s2*(np.log(avg_a015_s2/avg_a014_s2) - np.log(avg_a013_s2/avg_a014_s2))/(0.2), label = r'$\alpha_0$ ($-$42$\times$)')
plt.plot(lin_center, -8*avg_g31_s2*(np.log(avg_g35_s2/avg_g31_s2) - np.log(avg_g27_s2/avg_g31_s2))/(0.08), label = r'$\gamma$ ($-$8$\times$)')

plt.xlim([-14, 19])

plt.xlabel('[C II] intensity (kJy/sr)')
plt.ylabel(r'$\Delta$PRE/$\Delta \lambda$')
#plt.yscale('log')
#plt.xscale('log')
plt.title(r'$\Delta$PRE/$\Delta \lambda$ per intensity bin (Stage 2)')

plt.legend(loc = 'upper left', prop={'size':15})


plt.hlines(y = 0, xmin = lin_center[0], xmax = lin_center[-1], color = 'k', linestyle = '--')

#plt.savefig('paper_figs/seminar_dsrel/final_slide/dpre_forv6.pdf', bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_2225403/510032560.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:1: RuntimeWarning: invalid value encountered in subtract
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:2: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, avg_acii24_s2*(np.log(avg_acii28_s2/avg_acii24_s2) - np.log(avg_acii20_s2/avg_acii24_s2))/(0.028-0.020), '--', label = r'$\alpha_{[CII]}$')
# /tmp/ipykernel_2225403/510032560.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, avg_acii24_s2*(np.log(avg_acii28_s2/avg_acii24_s2) - np.log(avg_acii20_s2/avg_acii24_s2))/(0.028-0.020), '--', label = r'$\alpha_{[CII]}$')
# /tmp/ipykernel_2225403/510032560.py:3: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, 48*avg_mhi74_s2*(np.log(avg_mhi80_s2/avg_mhi74_s2) - np.log(avg_mhi68_s2/avg_mhi74_s2))/(0.80-0.68), '-.', label = r'$\alpha_{HI}$ (48$\times$)')
# /tmp/ipykernel_2225403/510032560.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(lin_center, 48*avg_mhi74_s2*(np.log(avg_mhi80_s2/avg_mhi74_s2) - np.log(avg_mhi68_s2/avg_mhi74_s2))/(0.80-0.68), '-.', label = r'$\alpha_{HI}$ (48$\times$)')
# /tmp/ipykernel_2225403/510032560.py:3: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, 48*avg_mhi74_s2*(np.log(avg_mhi80_s2/avg_mhi74_s2) - np.log(avg_mhi68_s2/avg_mhi74_s2))/(0.80-0.68), '-.', label = r'$\alpha_{HI}$ (48$\times$)')
# /tmp/ipykernel_2225403/510032560.py:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, -16*avg_mmin0_s2*(np.log(avg_mmin1_s2/avg_mmin0_s2) - np.log(avg_mmin9_s2/avg_mmin0_s2))/(10.1 - 9.9), '-.', label = r'log($M_{min}$) ($-$16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, -16*avg_mmin0_s2*(np.log(avg_mmin1_s2/avg_mmin0_s2) - np.log(avg_mmin9_s2/avg_mmin0_s2))/(10.1 - 9.9), '-.', label = r'log($M_{min}$) ($-$16$\times$)')
# /tmp/ipykernel_2225403/510032560.py:5: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, -42*avg_a014_s2*(np.log(avg_a015_s2/avg_a014_s2) - np.log(avg_a013_s2/avg_a014_s2))/(0.2), label = r'$\alpha_0$ ($-$42$\times$)')
# /tmp/ipykernel_2225403/510032560.py:5: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, -42*avg_a014_s2*(np.log(avg_a015_s2/avg_a014_s2) - np.log(avg_a013_s2/avg_a014_s2))/(0.2), label = r'$\alpha_0$ ($-$42$\times$)')
# /tmp/ipykernel_2225403/510032560.py:5: RuntimeWarning: invalid value encountered in subtract
#   plt.plot(lin_center, -42*avg_a014_s2*(np.log(avg_a015_s2/avg_a014_s2) - np.log(avg_a013_s2/avg_a014_s2))/(0.2), label = r'$\alpha_0$ ($-$42$\times$)')
# /tmp/ipykernel_2225403/510032560.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(lin_center, -8*avg_g31_s2*(np.log(avg_g35_s2/avg_g31_s2) - np.log(avg_g27_s2/avg_g31_s2))/(0.08), label = r'$\gamma$ ($-$8$\times$)')
# /tmp/ipykernel_2225403/510032560.py:6: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, -8*avg_g31_s2*(np.log(avg_g35_s2/avg_g31_s2) - np.log(avg_g27_s2/avg_g31_s2))/(0.08), label = r'$\gamma$ ($-$8$\times$)')
# /tmp/ipykernel_2225403/510032560.py:6: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, -8*avg_g31_s2*(np.log(avg_g35_s2/avg_g31_s2) - np.log(avg_g27_s2/avg_g31_s2))/(0.08), label = r'$\gamma$ ($-$8$\times$)')

# %% [markdown]
# odd zdex:

# %%
plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')

plt.xlim([-14, 19])

plt.xlabel('[C II] intensity (kJy/sr)')
plt.ylabel(r'$\Delta$PRE/$\Delta \lambda$')
#plt.yscale('log')
#plt.xscale('log')
plt.title(r'$\Delta$PRE/$\Delta \lambda$ per intensity bin (Stage 2)')

plt.legend(loc = 'upper left', prop={'size':15})

plt.hlines(y = 0, xmin = lin_center[0], xmax = lin_center[-1], color = 'k', linestyle = '--')
# Out:
# /tmp/ipykernel_2225403/1933723786.py:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/1933723786.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')
# /tmp/ipykernel_2225403/1933723786.py:1: RuntimeWarning: invalid value encountered in subtract
#   plt.plot(lin_center, 16*avg_zdex04_s2*(np.log(avg_zdex05_s2/avg_zdex04_s2) - np.log(avg_zdex03_s2/avg_zdex04_s2))/0.2, label = r'$\sigma_Z$ (16$\times$)')

# %%
plt.plot(lin_center, avg_zdex03_s2, label='$\sigma_Z$ = 0.3')
plt.plot(lin_center, avg_zdex04_s2, label='$\sigma_Z$ = 0.4')
plt.plot(lin_center, avg_zdex05_s2, label='$\sigma_Z$ = 0.5')
plt.yscale('log')
plt.xlabel('[C II] intensity (kJy/sr)')
plt.ylabel('N')
plt.legend()

# %%
plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex03_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.3/0.4')
plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex05_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.5/0.4')

plt.xlabel('[C II] intensity (kJy/sr)')
plt.ylabel('PRE')
#plt.yscale('log')
#plt.xscale('log')
plt.title('PRE per log-intensity bin')
plt.legend()

plt.hlines(y = 0, xmin = lin_center[0], xmax = lin_center[-1], color = 'k', linestyle = '--')

#plt.savefig('paper_figs/seminar_dsrel/pre_sig.pdf', bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_2225403/1799213946.py:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex03_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.3/0.4')
# /tmp/ipykernel_2225403/1799213946.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex03_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.3/0.4')
# /tmp/ipykernel_2225403/1799213946.py:2: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex05_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.5/0.4')
# /tmp/ipykernel_2225403/1799213946.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(lin_center, avg_zdex04_s2*np.log(avg_zdex05_s2/avg_zdex04_s2), label = r'$\Delta \sigma_Z$ = 0.5/0.4')
