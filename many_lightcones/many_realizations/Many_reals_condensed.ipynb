# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import astropy.units as u # I use astropy units in everything, very helpful for bookkeeping/debugging

from lim import lim # The base intensity mapping object
from datetime import datetime

matplotlib.rcParams.update({'font.size': 18,'figure.figsize':[8,7]}) # Make figures better
#matplotlib.rcParams,update({}'figure.figsize'] = [8,7]
from scipy.ndimage import gaussian_filter
plt.rcParams["mathtext.fontset"] = "dejavuserif"

lc_paths = '/home/dongwooc/scratchspace/pprun_hiz_npz/'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(lc_paths) if isfile(join(lc_paths, f))]
onlyfiles.remove('pksc2npz_5313591.out')
onlyfiles.remove('pksc2npz.sh')
for i in range(len(onlyfiles)):
    onlyfiles[i] = lc_paths+onlyfiles[i]
    
# Initialize LineModel with default model
m = lim()
m_cii = lim('Lichen_v4', doSim = True)
# Out:
# Input cosmological model does not match simulations
# Setting analytic cosmology to match simulation

# %%
m_cii.update(model_par = {'zdex': 0.4,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.028,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'},
            dnu = 2.8*u.GHz,
            nuObs = 270*u.GHz,
            Delta_nu = 40*u.GHz,
            tobs = np.inf*u.h,
            Omega_field = 4*u.deg**2,
            catalogue_file = '/home/dongwooc/scratchspace/pprun_hiz_npz/COMAP_z5.8-7.9_960Mpc_seed_13819.npz')

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    m_cii.update(catalogue_file = f"{onlyfiles[i]}")
    
    print('Loading', i, 'th lightcone...')
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/cii_beam'+str(i)+'.npy', m_cii.noise_added_map)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 17:27:51
# ------
# Loading 0 th lightcone...
# Loading .npz catalogues...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Loading .npz catalogues...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Loading .npz catalogues...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Loading .npz catalogues...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Loading .npz catalogues...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Loading .npz catalogues...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Loading .npz catalogues...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Loading .npz catalogues...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Loading .npz catalogues...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Loading .npz catalogues...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# ...

# %% [markdown]
# # Pixelization:

# %%
m_cii.update(model_par = {'zdex': 0.4,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'},
            dnu = 2.8*u.GHz,
            nuObs = 270*u.GHz,
            Delta_nu = 40*u.GHz,
            tobs = np.inf*u.h,
            Omega_field = 4*u.deg**2,
            catalogue_file = '/home/dongwooc/scratchspace/pprun_hiz_npz/COMAP_z5.8-7.9_960Mpc_seed_13819.npz')

# %%
def own_beam(m, sig, pix):
    
    '''
    m is the limlam object
    sig is the 3D cube of intensities
    pix is the pixelization blurring desired. default is 1.
    '''
    
    sm_map = gaussian_filter(sig, [pix, pix, 0])
    noise_sigma  = m.sigma_N
    noise_map    = np.random.normal(0, noise_sigma.to(u.Jy/u.sr, equivalencies=u.brightness_temperature(m.nuObs)).value, sig.shape)
    # print(noise_sigma.to(u.Jy/u.sr).value)
    sm_noise_map = sm_map + noise_map
    
    return sm_noise_map

# %%
sig_t = m_cii.maps
# Out:
# Loading .npz catalogues...

# %%
try_t = own_beam(m_cii, sig_t, 4/2)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 16))

plt.subplot(211)
plt.imshow(sig_t[:, :, 6], vmax = 2000, cmap =  'viridis', extent = [-1, 1, -1, 1])
plt.title(r'$Pure\ [C_{II}]\ Signal$')
plt.ylabel(r'$Dec\ (Degrees)$')
cb1 = plt.colorbar()
cb1.set_label(r'$Intensity\ (Jy/sr)$')

plt.subplot(212)
plt.imshow(try_t[:, :, 6], vmax = 2000, cmap =  'viridis', extent = [-1, 1, -1, 1])
plt.title(r'$Beamed\ [C_{II}]\ signal$')
plt.xlabel(r'$RA\ (Degrees)$')
plt.ylabel(r'$Dec\ (Degrees)$')
cb2 = plt.colorbar()
cb2.set_label(r'$Intensity\ (Jy/sr)$')

#plt.savefig('paper_figs/dsrel/sig_vs_beam_map.png')

# %%
m_cii.update(model_par = {'zdex': 0.3,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'},
            dnu = 2.8*u.GHz,
            nuObs = 270*u.GHz,
            Delta_nu = 40*u.GHz,
            tobs = np.inf*u.h,
            Omega_field = 4*u.deg**2,
            catalogue_file = '/home/dongwooc/scratchspace/pprun_hiz_npz/COMAP_z5.8-7.9_960Mpc_seed_13819.npz')

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:24:22
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:30:42
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:34:32
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:38:22
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:54:12
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 01:58:00
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:01:50
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:05:43
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:09:33
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:13:26
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:17:23
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 02:21:18
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/sig/cii_sig'+str(i)+'.npy')
    
    pix_0_5 = own_beam(m_cii, sig, 1/2)
    pix_1 = own_beam(m_cii, sig, 1)
    pix_1_5 = own_beam(m_cii, sig, 3/2)
    pix_2 = own_beam(m_cii, sig, 2)
    pix_4 = own_beam(m_cii, sig, 4)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/beam/pix_0-5/cii_beam'+str(i)+'.npy', pix_0_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/beam/pix_1/cii_beam'+str(i)+'.npy', pix_1)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/beam/pix_1-5/cii_beam'+str(i)+'.npy', pix_1_5)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/beam/pix_2/cii_beam'+str(i)+'.npy', pix_2)
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/beam/pix_4/cii_beam'+str(i)+'.npy', pix_4)
    
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:03:08
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %% [markdown]
# tobs = 1e6h

# %%
m_cii.update(model_par = {'zdex': 0.4,
 'M0': 1900000000.0,
 'Mmin': 20000000000,
 'alpha_MH1': 0.74,
 'alpha_LCII': 0.024,
 'alpha0': -1.412,
 'gamma0': 0.31,
 'BehrooziFile': 'sfr_reinterp.dat'},
            dnu = 2.8*u.GHz,
            nuObs = 270*u.GHz,
            Delta_nu = 40*u.GHz,
            tobs = (10**6)*u.h,
            Omega_field = 4*u.deg**2,
            catalogue_file = '/home/dongwooc/scratchspace/pprun_hiz_npz/COMAP_z5.8-7.9_960Mpc_seed_13819.npz')

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_31/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:13:56
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex03/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:15:48
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex05/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:24:04
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-020/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:25:13
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-028/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:26:19
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-68/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:27:29
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-80/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:28:39
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e9-9/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:29:50
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10-1/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:30:58
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_312/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:32:05
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_512/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:33:14
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_27/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:34:20
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Beginning time =", current_time)
print("------")

for i in range(len(onlyfiles)):
    
    print('Loading', i, 'th lightcone...')
    
    sig = np.load('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/sig/cii_sig'+str(i)+'.npy')
    
    for_pix1 = own_beam(m_cii, sig, 1)
    
    np.save('/mnt/scratch-lustre/horlaville/nuObs270/zdex04/alpha_cii_0-024/alpha_mhi_0-74/Mmin_2-10e10/alpha0_-1_412/gamma0_0_35/for/for_tobs1e6h/cii_for'+str(i)+'.npy', for_pix1)
    
    print('Finished loading', i, 'th lightcone!')
    
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("------")
print("Finished at =", current_time)
# Out:
# Beginning time = 18:35:28
# ------
# Loading 0 th lightcone...
# Finished loading 0 th lightcone!
# Loading 1 th lightcone...
# Finished loading 1 th lightcone!
# Loading 2 th lightcone...
# Finished loading 2 th lightcone!
# Loading 3 th lightcone...
# Finished loading 3 th lightcone!
# Loading 4 th lightcone...
# Finished loading 4 th lightcone!
# Loading 5 th lightcone...
# Finished loading 5 th lightcone!
# Loading 6 th lightcone...
# Finished loading 6 th lightcone!
# Loading 7 th lightcone...
# Finished loading 7 th lightcone!
# Loading 8 th lightcone...
# Finished loading 8 th lightcone!
# Loading 9 th lightcone...
# Finished loading 9 th lightcone!
# Loading 10 th lightcone...
# Finished loading 10 th lightcone!
# Loading 11 th lightcone...
# Finished loading 11 th lightcone!
# Loading 12 th lightcone...
# Finished loading 12 th lightcone!
# Loading 13 th lightcone...
# Finished loading 13 th lightcone!
# Loading 14 th lightcone...
# Finished loading 14 th lightcone!
# ...
